# %%
record={'1001':{'name':'cream','price':300,'qn':30,'m_date':'24-06-2021','e_date':'24-12-2021'},
        '1002':{'name':'eye cream','price':200,'qn':20,'m_date':'24-06-2021','e_date':'24-12-2021'},
        '1003':{'name':'makeup base','price':100,'qn':15,'m_date':'20-2-2021','e_date':'20-2-2022'},
        '1004':{'name':'foundation','price':350,'qn':50,'m_date':'13-4-2021','e_date':'13-4-2022'},
        '1005':{'name':'skin cover','price':150,'qn':25,'m_date':'25-6-2021','e_date':'24-12-2021'},
        '1006':{'name':'concealer','price':300,'qn':25,'m_date':'24-06-2021','e_date':'24-12-2021'},
        '1007':{'name':'compact powder','price':200,'qn':20,'m_date':'24-06-2021','e_date':'24-12-2021'},
        '1008':{'name':'powder','price':100,'qn':15,'m_date':'20-2-2021','e_date':'20-2-2022'},
        '1009':{'name':'eye shadow','price':150,'qn':50,'m_date':'13-4-2021','e_date':'13-4-2022'},
        '1010':{'name':'mascara','price':150,'qn':25,'m_date':'25-6-2021','e_date':'24-12-2021'},
        '1011':{'name':'eyeliner','price':250,'qn':30,'m_date':'24-06-2021','e_date':'24-12-2021'},
        '1012':{'name':'lipstick','price':150,'qn':20,'m_date':'24-06-2021','e_date':'24-12-2021'},
        '1013':{'name':'lip gloss','price':100,'qn':15,'m_date':'20-2-2021','e_date':'20-2-2022'},
        '1014':{'name':'sun block','price':350,'qn':50,'m_date':'13-4-2021','e_date':'13-4-2022'},
        '1015':{'name':'cleansing product','price':150,'qn':25,'m_date':'25-6-2021','e_date':'24-12-2021'},
        '1016':{'name':'sauce','price':150,'qn':50,'m_date':'24-06-2021','e_date':'24-12-2021'},
        '1017':{'name':'bread dipper','price':200,'qn':60,'m_date':'24-06-2021','e_date':'24-12-2021'},
        '1018':{'name':'vinegar','price':100,'qn':25,'m_date':'20-2-2021','e_date':'20-2-2022'},
        '1019':{'name':'olive oil','price':150,'qn':50,'m_date':'13-4-2021','e_date':'13-4-2022'},
        '1020':{'name':'spice rub','price':150,'qn':25,'m_date':'25-6-2021','e_date':'24-12-2021'},
        '1021':{'name':'pizza seasoning','price':150,'qn':30,'m_date':'24-06-2021','e_date':'24-12-2021'},
        '1022':{'name':'chocolate','price':200,'qn':20,'m_date':'24-06-2021','e_date':'24-12-2021'},
        '1023':{'name':'ketchup','price':100,'qn':15,'m_date':'20-2-2021','e_date':'20-2-2022'},
        '1024':{'name':'mustard','price':150,'qn':50,'m_date':'13-4-2021','e_date':'13-4-2022'},
        '1025':{'name':'butters','price':150,'qn':25,'m_date':'25-6-2021','e_date':'24-12-2021'},
        '1026':{'name':'jam','price':150,'qn':30,'m_date':'24-06-2021','e_date':'24-12-2021'},
        '1027':{'name':'jelly','price':150,'qn':20,'m_date':'24-06-2021','e_date':'24-12-2021'},
        '1028':{'name':'sea salt','price':100,'qn':15,'m_date':'20-2-2021','e_date':'20-2-2022'},
        '1029':{'name':'cane sugar','price':250,'qn':50,'m_date':'13-4-2021','e_date':'13-4-2022'},
        '1030':{'name':'compote','price':150,'qn':25,'m_date':'25-6-2021','e_date':'24-12-2021'}
        }

# %%
js=json.dumps(record)
fd=open("record.json","w")
fd.write(js)
fd.close()
# Out:
# {'1001': {'e_date': '24-12-2021',
#   'm_date': '24-06-2021',
#   'name': 'cream',
#   'price': 300,
#   'qn': 30},
#  '1002': {'e_date': '24-12-2021',
#   'm_date': '24-06-2021',
#   'name': 'eye cream',
#   'price': 200,
#   'qn': 20},
#  '1003': {'e_date': '20-2-2022',
#   'm_date': '20-2-2021',
#   'name': 'makeup base',
#   'price': 100,
#   'qn': 15},
#  '1004': {'e_date': '13-4-2022',
#   'm_date': '13-4-2021',
#   'name': 'foundation',
#   'price': 350,
#   'qn': 50},
#  '1005': {'e_date': '24-12-2021',
#   'm_date': '25-6-2021',
#   'name': 'skin cover',
#   'price': 150,
#   'qn': 25},
#  '1006': {'e_date': '24-12-2021',
#   'm_date': '24-06-2021',
#   'name': 'concealer',
#   'price': 300,
#   'qn': 25},
#  '1007': {'e_date': '24-12-2021',
#   'm_date': '24-06-2021',
#   'name': 'compact powder',
#   'price': 200,
#   'qn': 20},
#  '1008': {'e_date': '20-2-2022',
#   'm_date': '20-2-2021',
#   'name': 'powder',
#   'price': 100,
#   'qn': 15},
# ...

# %%
import os
import fileinput
import json

record={'1001':{'name':'cream','price':300,'qn':30,'m_date':'24-06-2021','e_date':'24-12-2021'},
        '1002':{'name':'eye cream','price':200,'qn':20,'m_date':'24-06-2021','e_date':'24-12-2021'},
        '1003':{'name':'makeup base','price':100,'qn':15,'m_date':'20-2-2021','e_date':'20-2-2022'},
        '1004':{'name':'foundation','price':350,'qn':50,'m_date':'13-4-2021','e_date':'13-4-2022'},
        '1005':{'name':'skin cover','price':150,'qn':25,'m_date':'25-6-2021','e_date':'24-12-2021'},
        '1006':{'name':'concealer','price':300,'qn':25,'m_date':'24-06-2021','e_date':'24-12-2021'},
        '1007':{'name':'compact powder','price':200,'qn':20,'m_date':'24-06-2021','e_date':'24-12-2021'},
        '1008':{'name':'powder','price':100,'qn':15,'m_date':'20-2-2021','e_date':'20-2-2022'},
        '1009':{'name':'eye shadow','price':150,'qn':50,'m_date':'13-4-2021','e_date':'13-4-2022'},
        '1010':{'name':'mascara','price':150,'qn':25,'m_date':'25-6-2021','e_date':'24-12-2021'},
        '1011':{'name':'eyeliner','price':250,'qn':30,'m_date':'24-06-2021','e_date':'24-12-2021'},
        '1012':{'name':'lipstick','price':150,'qn':20,'m_date':'24-06-2021','e_date':'24-12-2021'},
        '1013':{'name':'lip gloss','price':100,'qn':15,'m_date':'20-2-2021','e_date':'20-2-2022'},
        '1014':{'name':'sun block','price':350,'qn':50,'m_date':'13-4-2021','e_date':'13-4-2022'},
        '1015':{'name':'cleansing product','price':150,'qn':25,'m_date':'25-6-2021','e_date':'24-12-2021'},
        '1016':{'name':'sauce','price':150,'qn':50,'m_date':'24-06-2021','e_date':'24-12-2021'},
        '1017':{'name':'bread dipper','price':200,'qn':60,'m_date':'24-06-2021','e_date':'24-12-2021'},
        '1018':{'name':'vinegar','price':100,'qn':25,'m_date':'20-2-2021','e_date':'20-2-2022'},
        '1019':{'name':'olive oil','price':150,'qn':50,'m_date':'13-4-2021','e_date':'13-4-2022'},
        '1020':{'name':'spice rub','price':150,'qn':25,'m_date':'25-6-2021','e_date':'24-12-2021'},
        '1021':{'name':'pizza seasoning','price':150,'qn':30,'m_date':'24-06-2021','e_date':'24-12-2021'},
        '1022':{'name':'chocolate','price':200,'qn':20,'m_date':'24-06-2021','e_date':'24-12-2021'},
        '1023':{'name':'ketchup','price':100,'qn':15,'m_date':'20-2-2021','e_date':'20-2-2022'},
        '1024':{'name':'mustard','price':150,'qn':50,'m_date':'13-4-2021','e_date':'13-4-2022'},
        '1025':{'name':'butters','price':150,'qn':25,'m_date':'25-6-2021','e_date':'24-12-2021'},
        '1026':{'name':'jam','price':150,'qn':30,'m_date':'24-06-2021','e_date':'24-12-2021'},
        '1027':{'name':'jelly','price':150,'qn':20,'m_date':'24-06-2021','e_date':'24-12-2021'},
        '1028':{'name':'sea salt','price':100,'qn':15,'m_date':'20-2-2021','e_date':'20-2-2022'},
        '1029':{'name':'cane sugar','price':250,'qn':50,'m_date':'13-4-2021','e_date':'13-4-2022'},
        '1030':{'name':'compote','price':150,'qn':25,'m_date':'25-6-2021','e_date':'24-12-2021'}
        }

def menuDisplay():
    print('===============================')
    print('= Inventory Management System =')
    print('===============================')
    print('(1) Add New Item')
    print('(2) Remove Item')
    print('(3) Update Item')
    print('(4) Search Item')
    print('(5) Sell Inventory')
    print('(6) Print Inventory Report')
    print('(7) Quit')
    CHOICE = int(input("Enter choice: "))
    menuSelection(CHOICE)

def menuSelection(CHOICE):
    if CHOICE == 1:
        addInventory()
    elif CHOICE == 2:
        removeInventory()
    elif CHOICE == 3:
        updateInventory()
    elif CHOICE == 4:
        searchInventory()
    elif CHOICE == 5:
        sellInventory()    
    elif CHOICE == 6:
        printInventory()
    elif CHOICE == 7:
        exit()

def addInventory():
    
    print("Adding Inventory")
    print("================")
    prod_id=input("Enter Product Id :")
    name = input("Enter Product Name : ")
    price = input("Enter Product Price : ")
    qn=input("Enter Product Quantity :")
    m_date=input("Enter manufacture date :")
    e_date=input("Enetr expiry date :")
    record[prod_id]={'name':name,'price':price,'qn':qn,'m_date':m_date,'e_date':e_date}
    js=json.dumps(record)
    fd= open("record.json","a")
    fd.write(js)
    fd.close()
    CHOICE = input('Enter y to continue or n to exit: ')
    if CHOICE == 'y':
            menuDisplay()
    else:
        exit()
    
def removeInventory():
    print("Removing Inventory")
    print("==================")
    name = input("Enter the item name to remove from inventory: ")

    file = fileinput.input('record.json', inplace=True)

    for line in file:
         if name in line:
             for i in range(1):
                 next(file, None)
         else:
             print(line.strip('\n'), end='\n')
    name
    CHOICE = input('Enter y to continue or n to exit: ')
    if CHOICE == 'y':
            menuDisplay()
    else:
        exit()

def updateInventory():
    print("Updating Inventory")
    print("==================")
    name = input('Enter the item to update: ')
    qn = int(input("Enter the updated quantity. Enter - for less: "))

    with open('record.json', 'r') as f:
        filedata = f.readlines()

    replace = ""
    line_number = 0
    count = 0
    f = open('record.json','r')
    file = f.read().split('\n')
    for i, line in enumerate(file):
        if name in line:
            for b in file[i+1:i+2]:
                value = int(b)
                change = value + (qn)
                replace = b.replace(b, str(change))
                line_number = count
            count = i + 1      
    f.close()
    
    filedata[count] = replace + '\n'

    with open('record.json', 'w') as f:
        for line in filedata:
            f.write(line)
                                            
                
    CHOICE = input('Enter y to continue or n to exit: ')
    if CHOICE == 'y':
            menuDisplay()
    else:
        exit()

def searchInventory():
    print('Searching Inventory')
    print('===================')
    name = input('Enter the name of the item: ')
    
    f = open('record.json', 'r')
    search = f.readlines()
    f.close
    for i, line in enumerate(search):
        if name in line:
            for b in search[i:i+1]:
                print('Item:     ', b, end='')
            for c in search[i+1:i+2]:
                print('Quantity: ', c, end='')
                print('----------')
        
    CHOICE = input('Enter y to continue or n to exit: ')
    if CHOICE == 'y':
            menuDisplay()
    else:
        exit()

def sellInventory():
    print("sell Inventory")
    print("================")
    s_prod_id=input("Enter Product Id :")
    s_qn=int(input("Enter Quantity :"))
    prod_id=s_prod_id
    sell=record[prod_id]
    js=json.dumps(sell)
    fd= open("sell.json","a")
    fd.write(js)
    fd.close()
    CHOICE = input('Enter y to continue or n to exit: ')
    if CHOICE == 'y':
            menuDisplay()
    else:
        exit()        
        
def printInventory():
    InventoryFile = open('record.json', 'r')
    name = InventoryFile.readline()
    print('Current Inventory')
    print('-----------------')
    while name != '':
        qn = InventoryFile.readline()
        name = item_description.rstrip('\n')
        qn = item_quantity.rstrip('\n')
        print('Item:     ', name)
        print('Quantity: ', qn)
        print('----------')
        name = InventoryFile.readline()
    InventoryFile.close()

    CHOICE = input('Enter y to continue or n to exit: ')
    if CHOICE == 'y':
            menuDisplay()
    else:
        exit()

menuDisplay()
# Out:
# ...
# = Inventory Management System =
# ...
# (1) Add New Item
# (2) Remove Item
# (3) Update Item
# (4) Search Item
# (5) Sell Inventory
# (6) Print Inventory Report
# (7) Quit
# Enter choice: 5
# sell Inventory
# ...
# Enter Product Id :1001
# Enter Quantity :2
# Enter y to continue or n to exit: n
